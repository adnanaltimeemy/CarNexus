# %%
# Porsche UK Sales Dataset - Jupyter Notebook

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

data = {
    "Year": [2022, 2023, 2024],
    "Units_Sold_UK": [23495, 23495, 19393],  # 2022 and 2023 from reported numbers
    "Revenue_UK_GBP_m": [1340, 1920, 1620],   # approx revenue in £m
    "PreTaxProfit_UK_GBP_m": [35, 44.6, 39.2], # from Companies House numbers
}

uk_sales_df = pd.DataFrame(data)
uk_sales_dfplt.figure(figsize=(8,5))
plt.plot(uk_sales_df["Year"], uk_sales_df["Units_Sold_UK"], marker='o')
plt.title("Porsche UK Units Sold Over Time")
plt.xlabel("Year")
plt.ylabel("Units Sold")
plt.grid(True)
plt.show()
# Out:
#    Year  Units_Sold_UK  Revenue_UK_GBP_m  PreTaxProfit_UK_GBP_m
# 0  2022          23495              1340                   35.0
# 1  2023          23495              1920                   44.6
# 2  2024          19393              1620                   39.2

# %%
plt.figure(figsize=(8,5))
plt.plot(uk_sales_df["Year"], uk_sales_df["Units_Sold_UK"], marker='o')
plt.title("Porsche UK Units Sold Over Time")
plt.xlabel("Year")
plt.ylabel("Units Sold")
plt.grid(True)
plt.show()

# %%
uk_sales_df["Profit_Margin_%"] = (uk_sales_df["PreTaxProfit_UK_GBP_m"] / uk_sales_df["Revenue_UK_GBP_m"]) * 100
uk_sales_df
# Out:
#    Year  Units_Sold_UK  Revenue_UK_GBP_m  PreTaxProfit_UK_GBP_m  \
# 0  2022          23495              1340                   35.0
# 1  2023          23495              1920                   44.6
# 2  2024          19393              1620                   39.2
#
#    Profit_Margin_%
# 0         2.611940
# 1         2.322917
# 2         2.419753

# %%
# Example: reading SMMT registration stats
# smmt_data = pd.read_csv("smmt_car_registrations_uk.csv")
# print(smmt_data.head())

# %%
demo_data = {
    "Demographic": ["Avg_Age_Owner", "20-34_Segment_%", "Household_Income_GBP"],
    "Value": [42, 31, 150000]  # example / rough placeholders
}
demo_df = pd.DataFrame(demo_data)
demo_df
# Out:
#             Demographic   Value
# 0         Avg_Age_Owner      42
# 1       20-34_Segment_%      31
# 2  Household_Income_GBP  150000

# %%
plt.figure(figsize=(6,4))
plt.bar(demo_df["Demographic"], demo_df["Value"])
plt.title("Porsche UK Buyer Demographics (Sample)")
plt.ylabel("Value")
plt.show()
